# %% [markdown]
# This jupyter notebooks provides the code for classifying signals using the Continuous Wavelet Transform and Convolutional Neural Networks.
# To get some more background information, please have a look at the accompanying blog-post:
# http://ataspinar.com/2018/12/21/a-guide-for-using-the-wavelet-transform-in-machine-learning/

# %%
import pywt
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
from collections import defaultdict, Counter

import datetime, time

import tensorflow as tf
from tensorflow import keras

from keras.layers.experimental import preprocessing
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Dense, Flatten
from keras.models import Sequential
from keras.callbacks import History 


from tensorflow.keras.utils import to_categorical
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Load Triaining and Testing Datasets
file_path = '/storage/data/mit-bih'
file_name = 'mit_bih_data_set.csv'
dataset_path = os.path.join(file_path,file_name)
data_set = pd.read_csv(dataset_path,dtype=float)
num_classes=6
data_set_np = data_set.to_numpy()
X = data_set_np[:,:-1]
y = data_set_np[:,-1]

X_trn, X_tst, y_trn, y_tst = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

# %%
X.shape
# Out:
# (42020, 319)

# %%
scales = range(1,128)
wav = pywt.ContinuousWavelet('morl')
fs = 360
scalogram, freq = pywt.cwt(X[0], scales, wav, sampling_period = 1/fs)

plt.figure()
plt.subplots(2, figsize=(8, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(X.shape[1]),X[0])
plt.title('Signal')
plt.subplot(2, 1, 2)
plt.pcolormesh(scalogram)
plt.title('Scalogram')
# Out:
# Text(0.5, 1.0, 'Scalogram')

# %%
plt.imshow(scalogram)

# %% [markdown]
# ## 2. Applying a CWT to ECG signals and saving the resulting scaleogram into an numpy ndarray

# %%
train_data = np.ndarray(shape=(X_trn.shape[0], np.size(scales), X_trn.shape[1]))
test_data = np.ndarray(shape=(X_tst.shape[0], np.size(scales), X_tst.shape[1]))

for i, signal in enumerate(X_trn):
    train_data[i], _ = pywt.cwt(X_trn[i], scales, wav, sampling_period = 1/fs)
    
for i, signal in enumerate(X_tst):
    test_data[i], _ = pywt.cwt(X_tst[i], scales, wav, sampling_period = 1/fs)

# %%
train_data=train_data.astype('float32', copy=False)
test_data=test_data.astype('float32', copy=False)

# %%
m=np.mean(train_data)
s=np.std(train_data)

train_data = (train_data-m)/s
test_data = (test_data-m)/s

# prepare data for keras model
y_trn_oh = to_categorical(y_trn)
y_tst_oh = to_categorical(y_tst)

train_data = np.expand_dims(train_data, axis=3)
test_data = np.expand_dims(test_data, axis=3)

# %%
train_data.shape
# Out:
# (33616, 127, 319, 1)

# %%
train_data.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## 3. Training a Convolutional Neural Network

# %%
epochs = 100
batch_size = 500

model = Sequential()

model.add(Conv2D(8, 4, padding = 'same', activation='relu',
                input_shape=train_data.shape[1:4])) 
#model.add(Dropout(0.3))
model.add(MaxPooling2D(2, padding = 'same'))
#model.add(BatchNormalization())

model.add(Conv2D(4, 8, padding = 'same', activation='relu'))
#model.add(Dropout(0.3))
model.add(MaxPooling2D(2, padding = 'same'))
#model.add(BatchNormalization())

model.add(Conv2D(4, 8, activation='relu', padding = 'same'))
#model.add(Dropout(0.3))
#model.add(BatchNormalization())
model.add(MaxPooling2D(2, padding = 'same'))

model.add(Flatten())
#model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.5))

model.add(Dense(num_classes, activation='softmax'))

lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=1000,
    decay_rate=0.9)

opt = RMSprop(learning_rate=lr_schedule)

model.compile(loss='categorical_crossentropy', optimizer=opt, 
              metrics=['accuracy'])

callbacks = [EarlyStopping(monitor='val_loss', patience=20),
            ModelCheckpoint(filepath='./best_model_cwt.h5', monitor='val_accuracy', 
            save_best_only=True)]

# fit network
history=model.fit(train_data, y_trn_oh, epochs=epochs,callbacks=callbacks, 
                  batch_size=batch_size,validation_split=0.2)

model.load_weights('best_model_cwt.h5')

train_score = model.evaluate(train_data, y_trn_oh)
print('Train loss: {}, Train accuracy: {}'.format(train_score[0], train_score[1]))
test_score = model.evaluate(test_data, y_tst_oh)
print('Test loss: {}, Test accuracy: {}'.format(test_score[0], test_score[1]))
# Out:
# Epoch 1/100
# 54/54 [==============================] - 18s 205ms/step - loss: 1.3128 - accuracy: 0.5125 - val_loss: 0.2678 - val_accuracy: 0.9340
# Epoch 2/100
# 54/54 [==============================] - 9s 171ms/step - loss: 0.2721 - accuracy: 0.9237 - val_loss: 0.1561 - val_accuracy: 0.9521
# Epoch 3/100
# 54/54 [==============================] - 9s 172ms/step - loss: 0.1578 - accuracy: 0.9513 - val_loss: 0.4483 - val_accuracy: 0.8751
# Epoch 4/100
# 54/54 [==============================] - 9s 173ms/step - loss: 0.1773 - accuracy: 0.9479 - val_loss: 0.0616 - val_accuracy: 0.9827
# Epoch 5/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0893 - accuracy: 0.9751 - val_loss: 0.1238 - val_accuracy: 0.9631
# Epoch 6/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0641 - accuracy: 0.9822 - val_loss: 0.0675 - val_accuracy: 0.9789
# Epoch 7/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0486 - accuracy: 0.9849 - val_loss: 0.0525 - val_accuracy: 0.9865
# Epoch 8/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0497 - accuracy: 0.9842 - val_loss: 0.0349 - val_accuracy: 0.9909
# Epoch 9/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0435 - accuracy: 0.9872 - val_loss: 0.0429 - val_accuracy: 0.9893
# Epoch 10/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0386 - accuracy: 0.9884 - val_loss: 0.0463 - val_accuracy: 0.9877
# Epoch 11/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0489 - accuracy: 0.9859 - val_loss: 0.0395 - val_accuracy: 0.9897
# Epoch 12/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0811 - accuracy: 0.9771 - val_loss: 0.0449 - val_accuracy: 0.9875
# Epoch 13/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0276 - accuracy: 0.9922 - val_loss: 0.0507 - val_accuracy: 0.9868
# Epoch 14/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0273 - accuracy: 0.9917 - val_loss: 0.0373 - val_accuracy: 0.9920
# Epoch 15/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.0379 - val_accuracy: 0.9926
# Epoch 16/100
# 54/54 [==============================] - 9s 174ms/step - loss: 0.0480 - accuracy: 0.9893 - val_loss: 0.0334 - val_accuracy: 0.9915
# Epoch 17/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.0593 - val_accuracy: 0.9845
# Epoch 18/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0244 - accuracy: 0.9931 - val_loss: 0.0501 - val_accuracy: 0.9900
# Epoch 19/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0490 - val_accuracy: 0.9890
# Epoch 20/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0209 - accuracy: 0.9934 - val_loss: 0.0330 - val_accuracy: 0.9921
# Epoch 21/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0560 - val_accuracy: 0.9896
# Epoch 22/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.0483 - val_accuracy: 0.9900
# Epoch 23/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0162 - accuracy: 0.9943 - val_loss: 0.0997 - val_accuracy: 0.9749
# Epoch 24/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0491 - val_accuracy: 0.9914
# Epoch 25/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0506 - val_accuracy: 0.9914
# Epoch 26/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0459 - val_accuracy: 0.9905
# Epoch 27/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0788 - accuracy: 0.9803 - val_loss: 0.1110 - val_accuracy: 0.9615
# Epoch 28/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0560 - val_accuracy: 0.9869
# Epoch 29/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0518 - val_accuracy: 0.9911
# Epoch 30/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0582 - val_accuracy: 0.9868
# Epoch 31/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.0480 - val_accuracy: 0.9908
# Epoch 32/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0470 - val_accuracy: 0.9942
# Epoch 33/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0619 - val_accuracy: 0.9915
# Epoch 34/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0650 - val_accuracy: 0.9897
# Epoch 35/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0599 - val_accuracy: 0.9903
# Epoch 36/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0566 - val_accuracy: 0.9918
# Epoch 37/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.1418 - val_accuracy: 0.9829
# Epoch 38/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.0784 - val_accuracy: 0.9877
# Epoch 39/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0829 - val_accuracy: 0.9857
# Epoch 40/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.0623 - val_accuracy: 0.9912
# 1051/1051 [==============================] - 6s 5ms/step - loss: 0.0135 - accuracy: 0.9977
# Train loss: 0.013517757877707481, Train accuracy: 0.9977391958236694
# 263/263 [==============================] - 2s 6ms/step - loss: 0.0674 - accuracy: 0.9908
# Test loss: 0.06741885095834732, Test accuracy: 0.9908376932144165

# %%
print(tf.config.experimental.get_memory_usage("GPU:0"))
# Out:
# 223488

# %%
def evaluate_model(history,X_test,y_test,model):
    scores = model.evaluate((X_test),y_test, verbose=0)
    print("Accuracy: %.2f%%" % (scores[1]*100))
    
    print(history)
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model - Accuracy')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model- Loss')
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.show()
    target_names=['0','1','2','3','4','5']
    
    y_true=[]
    for element in y_test:
        y_true.append(np.argmax(element))
    prediction_proba=model.predict(X_test)
    prediction=np.argmax(prediction_proba,axis=1)

# %%
# %%time
evaluate_model(history,test_data,y_tst_oh,model)
y_pred=model.predict(test_data)
# Out:
# Accuracy: 99.08%
# <tensorflow.python.keras.callbacks.History object at 0x7f72600440f0>
# CPU times: user 6.53 s, sys: 3 s, total: 9.53 s
# Wall time: 7.34 s

# %%
with tf.device('/cpu:0'):
    start = time.time()
    model.predict(test_data)
    end = time.time()

inference_time =  (end-start)/test_data.shape[0]
throughput = test_data.shape[0]/(end-start)

print("Inference on CPU is :", inference_time)
print("Throughput on CPU is :", throughput, "sequence per second")
# Out:
# Inference on CPU is : 0.0021354388702715765
# Throughput on CPU is : 468.28781377048927 sequence per second

# %%
with tf.device('/gpu:0'):
    start = time.time()
    model.predict(test_data)
    end = time.time()

inference_time =  (end-start)/test_data.shape[0]
throughput = test_data.shape[0]/(end-start)

print("Inference on GPU is :", inference_time)
print("Throughput on GPU is :", throughput, "sequence per second")
# Out:
# Inference on GPU is : 0.00027794454393927
# Throughput on GPU is : 3597.8400073163402 sequence per second

# %%
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_tst_oh.argmax(axis=1), y_pred.argmax(axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['N', 'L', 'R', 'A', 'V', '/'],normalize=True,
                      title='Confusion matrix, with normalization')
plt.show()
# Out:
# Normalized confusion matrix

# %%
import plotting

classes = ['N', 'L', 'R', 'A', 'V', '/']

y_keras = model.predict(test_data)
print("Accuracy: {}".format(accuracy_score(np.argmax(y_tst_oh, axis=1), np.argmax(y_keras, axis=1))))
plt.figure(figsize=(9,9))
_ = plotting.makeRoc(y_tst_oh, y_keras, classes)
# Out:
# Accuracy: 0.9908376963350786

# %%
def get_flops(model):
    session = tf.compat.v1.Session()
    graph = tf.compat.v1.get_default_graph()   

    with graph.as_default():
        with session.as_default():
            model = tf.keras.models.load_model(model)

            run_meta = tf.compat.v1.RunMetadata()
            opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        
            # We use the Keras session graph in the call to the profiler.
            flops = tf.compat.v1.profiler.profile(graph=graph,
                                                  run_meta=run_meta, cmd='op', options=opts)
        
            return flops.total_float_ops

get_flops('best_model_cwt.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 37128

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True, show_dtype=True)
#tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=False, show_dtype=False, show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 127, 319, 8)       136
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 160, 8)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 160, 4)        2052
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 80, 4)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 80, 4)         1028
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 40, 4)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2560)              0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 15366
# =================================================================
# Total params: 18,582
# Trainable params: 18,582
# Non-trainable params: 0
# _________________________________________________________________
