# %%
import numpy as np
import pandas as pd
import os

from collections import defaultdict, Counter

import tensorflow as tf
from tensorflow import keras

from datetime import datetime
import time

from keras.layers.experimental import preprocessing
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization, Dropout, Input, Dense, Flatten
from keras.models import Sequential
from keras.callbacks import History 


from keras.utils import to_categorical
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score


import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#%pdb

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# Load Dataset
#
# https://physionet.org/content/mitdb/1.0.0/
#
# Background
#
# Since 1975, our laboratories at Boston's Beth Israel Hospital (now the Beth Israel Deaconess Medical Center) and at MIT have supported our own research into arrhythmia analysis and related subjects. One of the first major products of that effort was the MIT-BIH Arrhythmia Database, which we completed and began distributing in 1980. The database was the first generally available set of standard test material for evaluation of arrhythmia detectors, and has been used for that purpose as well as for basic research into cardiac dynamics at more than 500 sites worldwide. Originally, we distributed the database on 9-track half-inch digital tape at 800 and 1600 bpi, and on quarter-inch IRIG-format FM analog tape. In August, 1989, we produced a CD-ROM version of the database.
#
# Data Description
#
# The MIT-BIH Arrhythmia Database contains 48 half-hour excerpts of two-channel ambulatory ECG recordings, obtained from 47 subjects studied by the BIH Arrhythmia Laboratory between 1975 and 1979. Twenty-three recordings were chosen at random from a set of 4000 24-hour ambulatory ECG recordings collected from a mixed population of inpatients (about 60%) and outpatients (about 40%) at Boston's Beth Israel Hospital; the remaining 25 recordings were selected from the same set to include less common but clinically significant arrhythmias that would not be well-represented in a small random sample.
#
# The recordings were digitized at 360 samples per second per channel with 11-bit resolution over a 10 mV range. Two or more cardiologists independently annotated each record; disagreements were resolved to obtain the computer-readable reference annotations for each beat (approximately 110,000 annotations in all) included with the database.

# %%
# Load Triaining and Testing Datasets
# Local
file_path = '../mitbihcsv'
#Paperspace
#file_path = '/storage/data/mit-bih'

file_name = 'mit_bih_data_set.csv'
dataset_path = os.path.join(file_path,file_name)
data_set = pd.read_csv(dataset_path,dtype=float)
num_classes=6
data_set_np = data_set.to_numpy()
X = data_set_np[:,:-1].astype('float32')
y = data_set_np[:,-1]

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

X_trn, X_tst, y_trn, y_tst = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

y_trn_oh = to_categorical(y_trn)
y_tst_oh = to_categorical(y_tst)

X_trn_tf = np.expand_dims(X_trn, axis=2)
X_tst_tf = np.expand_dims(X_tst, axis=2)


#X_tst = X_tst.astype('float32')
#X_tst_tf = X_tst_tf.astype('float32')

# %% [markdown]
# ## 3. Training a 1D Convolutional Neural Network

# %%
epochs = 100
batch_size = 500
validation_split = 0.2 # 20% of training set will be used for validation set. 

model = Sequential()

model.add(Conv1D(16, 8, activation='relu', padding="same",
                 input_shape=X_trn_tf[1,:].shape,
                 name='Conv1DLayer1'))
model.add(MaxPooling1D(4, padding='same'))
    
model.add(Conv1D(16, 8, activation='relu', padding="same", name='Conv1DLayer2'))
model.add(MaxPooling1D(4, padding='same'))
    
model.add(Conv1D(16, 16, activation='relu', padding="same", name='Conv1DLayer3'))

model.add(Flatten())

model.add(Dense(num_classes, activation='softmax', name = 'OuputLayer'))

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-2,
                                                             decay_steps=1000,decay_rate=0.9)

opt = RMSprop(learning_rate=lr_schedule)

model.compile(loss='categorical_crossentropy', optimizer=opt, 
              metrics=['accuracy'])

#logs = "logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")

#tboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logs,
#                                                 histogram_freq = 1,
#                                                 profile_batch = '30,80')


callbacks = [EarlyStopping(monitor='val_loss', patience=50),
             ModelCheckpoint(filepath='./base_model.h5', 
                             monitor='val_accuracy', save_best_only=True)]
             #, tboard_callback]

# fit network
history=model.fit(X_trn_tf, y_trn_oh, epochs=epochs,callbacks=callbacks, 
                  batch_size=batch_size,validation_split=validation_split)

model.load_weights('base_model.h5')

train_score = model.evaluate(X_trn_tf, y_trn_oh)
print('Train loss: {}, Train accuracy: {}'.format(train_score[0], train_score[1]))
test_score = model.evaluate(X_tst_tf, y_tst_oh)
print('Test loss: {}, Test accuracy: {}'.format(test_score[0], test_score[1]))
# Out:
# Epoch 1/100
# 54/54 [==============================] - 3s 29ms/step - loss: 1.2181 - accuracy: 0.5812 - val_loss: 0.1404 - val_accuracy: 0.9621
# Epoch 2/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.1429 - accuracy: 0.9593 - val_loss: 0.0796 - val_accuracy: 0.9790
# Epoch 3/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0879 - accuracy: 0.9758 - val_loss: 0.0802 - val_accuracy: 0.9805
# Epoch 4/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0686 - accuracy: 0.9817 - val_loss: 0.0524 - val_accuracy: 0.9878
# Epoch 5/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0520 - accuracy: 0.9850 - val_loss: 0.0534 - val_accuracy: 0.9883
# Epoch 6/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0378 - accuracy: 0.9891 - val_loss: 0.0528 - val_accuracy: 0.9866
# Epoch 7/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0327 - accuracy: 0.9907 - val_loss: 0.0564 - val_accuracy: 0.9874
# Epoch 8/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.0451 - val_accuracy: 0.9894
# Epoch 9/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0269 - accuracy: 0.9927 - val_loss: 0.0452 - val_accuracy: 0.9911
# Epoch 10/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0198 - accuracy: 0.9939 - val_loss: 0.0538 - val_accuracy: 0.9902
# Epoch 11/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.0437 - val_accuracy: 0.9906
# Epoch 12/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0191 - accuracy: 0.9941 - val_loss: 0.0629 - val_accuracy: 0.9896
# Epoch 13/100
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.1285 - val_accuracy: 0.9769
# Epoch 14/100
# 54/54 [==============================] - 2s 36ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 0.0560 - val_accuracy: 0.9903
# Epoch 15/100
# 54/54 [==============================] - 2s 37ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0558 - val_accuracy: 0.9915
# Epoch 16/100
# 54/54 [==============================] - 2s 42ms/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 0.0568 - val_accuracy: 0.9918
# Epoch 17/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.0526 - val_accuracy: 0.9914
# Epoch 18/100
# 54/54 [==============================] - 2s 35ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0580 - val_accuracy: 0.9909
# Epoch 19/100
# 54/54 [==============================] - 2s 35ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.0459 - val_accuracy: 0.9926
# Epoch 20/100
# 54/54 [==============================] - 2s 35ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0586 - val_accuracy: 0.9897
# Epoch 21/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.0687 - val_accuracy: 0.9905
# Epoch 22/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 0.0528 - val_accuracy: 0.9932
# Epoch 23/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0590 - val_accuracy: 0.9924
# Epoch 24/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0154 - accuracy: 0.9963 - val_loss: 0.0716 - val_accuracy: 0.9885
# Epoch 25/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.0711 - val_accuracy: 0.9927
# Epoch 26/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0665 - val_accuracy: 0.9911
# Epoch 27/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0095 - accuracy: 0.9977 - val_loss: 0.0740 - val_accuracy: 0.9926
# Epoch 28/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0771 - val_accuracy: 0.9893
# Epoch 29/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0122 - accuracy: 0.9971 - val_loss: 0.0734 - val_accuracy: 0.9932
# Epoch 30/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.0872 - val_accuracy: 0.9927
# Epoch 31/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0765 - val_accuracy: 0.9933
# Epoch 32/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0121 - accuracy: 0.9978 - val_loss: 0.0711 - val_accuracy: 0.9930
# Epoch 33/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0100 - accuracy: 0.9977 - val_loss: 0.0793 - val_accuracy: 0.9930
# Epoch 34/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.0706 - val_accuracy: 0.9941
# Epoch 35/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0114 - accuracy: 0.9984 - val_loss: 0.0760 - val_accuracy: 0.9938
# Epoch 36/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.1004 - val_accuracy: 0.9880
# Epoch 37/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0690 - val_accuracy: 0.9938
# Epoch 38/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0963 - val_accuracy: 0.9909
# Epoch 39/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0971 - val_accuracy: 0.9894
# Epoch 40/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0749 - val_accuracy: 0.9933
# Epoch 41/100
# 54/54 [==============================] - 2s 32ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.1113 - val_accuracy: 0.9912
# Epoch 42/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0877 - val_accuracy: 0.9924
# Epoch 43/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0947 - val_accuracy: 0.9915
# Epoch 44/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.0830 - val_accuracy: 0.9926
# Epoch 45/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.1058 - val_accuracy: 0.9903
# Epoch 46/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.1080 - val_accuracy: 0.9923
# Epoch 47/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0959 - val_accuracy: 0.9932
# Epoch 48/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.1114 - val_accuracy: 0.9927
# Epoch 49/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.1208 - val_accuracy: 0.9924
# Epoch 50/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1012 - val_accuracy: 0.9932
# Epoch 51/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0096 - accuracy: 0.9981 - val_loss: 0.1315 - val_accuracy: 0.9926
# Epoch 52/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.1180 - val_accuracy: 0.9920
# Epoch 53/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.1000 - val_accuracy: 0.9927
# Epoch 54/100
# 54/54 [==============================] - 2s 35ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.1198 - val_accuracy: 0.9923
# Epoch 55/100
# 54/54 [==============================] - 2s 33ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.1550 - val_accuracy: 0.9893
# Epoch 56/100
# 54/54 [==============================] - 2s 36ms/step - loss: 0.0108 - accuracy: 0.9983 - val_loss: 0.1068 - val_accuracy: 0.9932
# Epoch 57/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.1099 - val_accuracy: 0.9929
# Epoch 58/100
# 54/54 [==============================] - 2s 35ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.1138 - val_accuracy: 0.9926
# Epoch 59/100
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.1340 - val_accuracy: 0.9915
# Epoch 60/100
# 54/54 [==============================] - 2s 36ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.1107 - val_accuracy: 0.9935
# Epoch 61/100
# 54/54 [==============================] - 2s 34ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.1217 - val_accuracy: 0.9933
# 1051/1051 [==============================] - 6s 6ms/step - loss: 0.0173 - accuracy: 0.9982
# Train loss: 0.017301663756370544, Train accuracy: 0.998185396194458
# 263/263 [==============================] - 2s 7ms/step - loss: 0.0583 - accuracy: 0.9923
# Test loss: 0.05829339474439621, Test accuracy: 0.9922655820846558

# %% [markdown]
# # Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %% [markdown]
# # Launch TensorBoard and navigate to the Profile tab to view performance profile
# %tensorboard --logdir=logs

# %%
def evaluate_model(history,X_test,y_test,model):
    scores = model.evaluate((X_test),y_test, verbose=0)
    print("Accuracy: %.2f%%" % (scores[1]*100))
    
    print(history)
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model - Accuracy')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model- Loss')
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.show()
    target_names=['0','1','2','3','4','5']
    
    y_true=[]
    for element in y_test:
        y_true.append(np.argmax(element))
    prediction_proba=model.predict(X_test)
    prediction=np.argmax(prediction_proba,axis=1)
    cnf_matrix = confusion_matrix(y_true, prediction)

# %%
print(tf.config.experimental.get_memory_usage("GPU:0"))
# Out:
# 600576

# %%
# %%time
evaluate_model(history,X_tst_tf,y_tst_oh,model)
y_pred=model.predict(X_tst_tf)
# Out:
# Accuracy: 99.23%
# <tensorflow.python.keras.callbacks.History object at 0x000001D9F8DAE370>
# Wall time: 3.68 s

# %%
with tf.device('/cpu:0'):
    start = time.time()
    model.predict(X_tst_tf)
    end = time.time()

inference_time =  (end-start)/X_tst_tf.shape[0]
throughput = X_tst_tf.shape[0]/(end-start)

print("Inference on CPU is :", inference_time)
print("Throughput on CPU is :", throughput, "sequence per second")
# Out:
# Inference on CPU is : 0.00019864724511932272
# Throughput on CPU is : 5034.049172941329 sequence per second

# %%
with tf.device('/gpu:0'):
    start = time.time()
    model.predict(X_tst_tf)
    end = time.time()

inference_time =  (end-start)/X_tst_tf.shape[0]
throughput = X_tst_tf.shape[0]/(end-start)

print("Inference on GPU is :", inference_time)
print("Throughput on GPU is :", throughput, "sequence per second")
# Out:
# Inference on GPU is : 0.00013005086661860353
# Throughput on GPU is : 7689.299010460818 sequence per second

# %%
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_tst_oh.argmax(axis=1), y_pred.argmax(axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['N', 'L', 'R', 'A', 'V', '/'],normalize=True,
                      title='Confusion matrix, with normalization')
plt.show()
# Out:
# Normalized confusion matrix

# %%
import plotting

classes = ['N', 'L', 'R', 'A', 'V', '/']

y_keras = model.predict(X_tst_tf)
print("Accuracy: {}".format(accuracy_score(np.argmax(y_tst_oh, axis=1), np.argmax(y_keras, axis=1))))
plt.figure(figsize=(9,9))
_ = plotting.makeRoc(y_tst_oh, y_keras, classes)
# Out:
# Accuracy: 0.992265587815326

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True, show_dtype=True)
#tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=False, show_dtype=False, show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96)

# %%
#!pip install tf_agents==0.7.1
#!pip install tensorflow_probability==0.12.2

# %%
from plot_model import plot_model
plot_model(model,to_file='base_model.png', show_shapes=True, show_layer_names=False, rankdir='TB', expand_nested=False, style=0, color=True, dpi=96)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv1DLayer1 (Conv1D)        (None, 319, 16)           144
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 80, 16)            0
# _________________________________________________________________
# Conv1DLayer2 (Conv1D)        (None, 80, 16)            2064
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 20, 16)            0
# _________________________________________________________________
# Conv1DLayer3 (Conv1D)        (None, 20, 16)            4112
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 320)               0
# _________________________________________________________________
# OuputLayer (Dense)           (None, 6)                 1926
# =================================================================
# Total params: 8,246
# Trainable params: 8,246
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Tensorflow Optimization Toolkit does not support Conv1D

# %% [markdown]
# ## Convert best model to tflite with floating points

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

base_model_size = os.stat('base_model.h5').st_size / 1024
print('Base model size = %dKBs.' % base_model_size)

tflite_model_size = len(tflite_model) / 1024
print('tflite model size = %dKBs.' % tflite_model_size)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmpiy2wk9qc\assets
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmpiy2wk9qc\assets
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# Base model size = 102KBs.
# tflite model size = 37KBs.

# %% [markdown]
# ## Run tflite interpreter to compute inference result of specific input

# %%
# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_content=tflite_model)
interpreter.allocate_tensors()

#get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

#Preprocess the image to required size and cast
input_shape = input_details[0]['shape']
input_data = np.expand_dims(X_tst_tf[0], 0)

#set the tensor to point to the input data to be inferred
input_index = interpreter.get_input_details()[0]["index"]
interpreter.set_tensor(input_details[0]['index'], input_data)

#Run the inference
interpreter.invoke()
output_details = interpreter.get_tensor(output_details[0]['index'])

# %%
# A helper function to evaluate the TF Lite model using "test" dataset.
def evaluate_tflite_model(tflite_model):
  # Initialize TFLite interpreter using the model.
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()
  input_tensor_index = interpreter.get_input_details()[0]["index"]
  output = interpreter.tensor(interpreter.get_output_details()[0]["index"])

  # Run predictions on every image in the "test" dataset.
  prediction_outputs = []
  for data in X_tst_tf:
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_data = np.expand_dims(data, axis=0).astype(np.float32)
    interpreter.set_tensor(input_tensor_index, test_data)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the digit with highest
    # probability.
    prediction = np.argmax(output()[0])
    prediction_outputs.append(prediction)

  # Compare prediction results with ground truth labels to calculate accuracy.
  accurate_count = 0
  for index in range(len(prediction_outputs)):
    if prediction_outputs[index] == y_tst[index]:
      accurate_count += 1
  accuracy = accurate_count * 1.0 / len(prediction_outputs)

  return accuracy

# %%
# Evaluate the TF Lite float model. You'll find that its accurary is identical
# to the original TF (Keras) model because they are essentially the same model
# stored in different format.
tflite_accuracy = evaluate_tflite_model(tflite_model)
print('tflite model accuracy = %.4f' % tflite_accuracy)
# Out:
# tflite model accuracy = 0.9923

# %%
# Save the tflite model to file to the Downloads directory
f = open('float32.tflite', "wb")
f.write(tflite_model)
f.close()

# %% [markdown]
# ## Dynamic range quantization of tflite from best model

# %%
# Re-convert the model to TF Lite using quantization.
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Set float16 is the supported type on the target platform
converter.target_spec.supported_types = [tf.float16]

tflite_qmodel = converter.convert()

# Show model size in KBs.
quantized_model_size = len(tflite_qmodel) / 1024
print('Quantized model size = %dKBs,' % quantized_model_size)
print('which is about %d%% of the float model size.'\
      % (quantized_model_size * 100 / tflite_model_size))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmpcbrbywhw\assets
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmpcbrbywhw\assets
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# Quantized model size = 23KBs,
# which is about 61% of the float model size.

# %%
# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_content=tflite_qmodel)
interpreter.allocate_tensors()

#get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

#Preprocess the image to required size and cast
input_shape = input_details[0]['shape']
input_data = np.expand_dims(X_tst_tf[0], 0)

#set the tensor to point to the input data to be inferred
input_index = interpreter.get_input_details()[0]["index"]
interpreter.set_tensor(input_details[0]['index'], input_data)

#Run the inference
interpreter.invoke()
output_details = interpreter.get_tensor(output_details[0]['index'])

# %%
# Save the quantized model to file to the Downloads directory
f = open('quant_float16.tflite', "wb")
f.write(tflite_qmodel)
f.close()

# %%
# Evalualte the TF Lite quantized model.
# Don't be surprised if you see quantized model accuracy is higher than
# the original float model. It happens sometimes :)

quantized_tflite_accuracy = evaluate_tflite_model(tflite_qmodel)
print('Quantized float 16 model accuracy = %.4f' % quantized_tflite_accuracy)

print('Accuracy drop = %.4f' % (tflite_accuracy - quantized_tflite_accuracy))
# Out:
# Quantized float 16 model accuracy = 0.9923
# Accuracy drop = 0.0000

# %% [markdown]
# ## Int8 Qkeras Quantization of tflite model

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from collections import defaultdict

from qkeras import *

# %%
def CreateQModel(X_train,y_train,X_test,y_test):
    X = x_in = Input(shape = X_train[1,:].shape)
    
    #quantized_bits(bits, integer, symmetric, keep_negative, alpha, use_stochastic_rouding)

    X = QConv1D(16, 8,padding="same",
                      kernel_quantizer="quantized_bits(8, 0, 1)", 
                      bias_quantizer="quantized_bits(8, 0, 1)",
                      name="Qconv1d_1")(X)
    X = QActivation("quantized_relu(8,0)")(X)
    X = MaxPooling1D(4, padding='same')(X)

    X = QConv1D(16, 8,padding="same",
                      kernel_quantizer="quantized_bits(8, 0, 1)", 
                      bias_quantizer="quantized_bits(8, 0, 1)",
                      name="Qconv1d_2")(X)
    X = QActivation("quantized_relu(8,0)")(X)
    X = MaxPooling1D(4, padding='same')(X)
    
    X = QConv1D(16, 8,padding="same",
                      kernel_quantizer="quantized_bits(8, 0, 1)", 
                      bias_quantizer="quantized_bits(8, 0, 1)",
                      name="Qconv1d_3")(X)
    X = QActivation("quantized_relu(8,0)")(X)

    X = Flatten()(X)

    X = QDense(num_classes, 
               kernel_quantizer="quantized_bits(8, 0, 1)", 
               bias_quantizer="quantized_bits(8, 0, 1)",
               name = 'OuputLayer')(X)
    X = Activation("softmax")(X)
    
    qmodel = Model(inputs=x_in, outputs=X)
    
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-2,
                                                             decay_steps=1000,decay_rate=0.9)
    opt = RMSprop(learning_rate=lr_schedule)
    
    qmodel.compile(loss='categorical_crossentropy', optimizer=opt, 
                  metrics=['accuracy'])
    callbacks = [EarlyStopping(monitor='val_loss', patience=50),
                 ModelCheckpoint(filepath='./qkeras_int16_model.h5', 
                                 monitor='val_accuracy', save_best_only=True)]


    # fit network
    history=qmodel.fit(X_train, y_train, epochs=epochs,callbacks=callbacks, 
                      batch_size=batch_size,validation_split=validation_split,shuffle=True)

    qmodel.load_weights('qkeras_int16_model.h5')

    train_score = qmodel.evaluate(X_trn_tf, y_trn_oh)
    print('Train loss: {}, Train accuracy: {}'.format(train_score[0], train_score[1]))
    test_score = qmodel.evaluate(X_tst_tf, y_tst_oh)
    print('Test loss: {}, Test accuracy: {}'.format(test_score[0], test_score[1]))

    return(qmodel,history)

# %%
qmodel,history = CreateQModel(X_trn_tf,y_trn_oh,X_tst_tf,y_tst_oh)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 13s 110ms/step - loss: 1.3113 - accuracy: 0.5614 - val_loss: 0.2076 - val_accuracy: 0.9447
# Epoch 2/100
# 54/54 [==============================] - 3s 60ms/step - loss: 0.1750 - accuracy: 0.9504 - val_loss: 0.0765 - val_accuracy: 0.9772
# Epoch 3/100
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0873 - accuracy: 0.9725 - val_loss: 0.0577 - val_accuracy: 0.9845
# Epoch 4/100
# 54/54 [==============================] - 3s 57ms/step - loss: 0.0554 - accuracy: 0.9833 - val_loss: 0.0548 - val_accuracy: 0.9838
# Epoch 5/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0428 - accuracy: 0.9862 - val_loss: 0.0391 - val_accuracy: 0.9880
# Epoch 6/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0386 - accuracy: 0.9880 - val_loss: 0.0467 - val_accuracy: 0.9859
# Epoch 7/100
# 54/54 [==============================] - 3s 56ms/step - loss: 0.0341 - accuracy: 0.9898 - val_loss: 0.0488 - val_accuracy: 0.9857
# Epoch 8/100
# 54/54 [==============================] - 3s 56ms/step - loss: 0.0292 - accuracy: 0.9916 - val_loss: 0.0366 - val_accuracy: 0.9899
# Epoch 9/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0247 - accuracy: 0.9915 - val_loss: 0.0368 - val_accuracy: 0.9884
# Epoch 10/100
# 54/54 [==============================] - 3s 60ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0368 - val_accuracy: 0.9888
# Epoch 11/100
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 0.0387 - val_accuracy: 0.9887
# Epoch 12/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0232 - accuracy: 0.9932 - val_loss: 0.0700 - val_accuracy: 0.9759
# Epoch 13/100
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0484 - val_accuracy: 0.9850
# Epoch 14/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.0391 - val_accuracy: 0.9881
# Epoch 15/100
# 54/54 [==============================] - 3s 57ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 0.0337 - val_accuracy: 0.9899
# Epoch 16/100
# 54/54 [==============================] - 3s 57ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0322 - val_accuracy: 0.9911
# Epoch 17/100
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0477 - val_accuracy: 0.9860
# Epoch 18/100
# 54/54 [==============================] - 3s 56ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0374 - val_accuracy: 0.9897
# Epoch 19/100
# 54/54 [==============================] - 3s 57ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0516 - val_accuracy: 0.9869
# Epoch 20/100
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0298 - val_accuracy: 0.9917
# Epoch 21/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0103 - accuracy: 0.9975 - val_loss: 0.0326 - val_accuracy: 0.9914
# Epoch 22/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0329 - val_accuracy: 0.9917
# Epoch 23/100
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0358 - val_accuracy: 0.9908
# Epoch 24/100
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0369 - val_accuracy: 0.9911
# Epoch 25/100
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.0327 - val_accuracy: 0.9914
# Epoch 26/100
# 54/54 [==============================] - 3s 58ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0524 - val_accuracy: 0.9866
# Epoch 27/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0358 - val_accuracy: 0.9914
# Epoch 28/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0330 - val_accuracy: 0.9915
# Epoch 29/100
# 54/54 [==============================] - 3s 55ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0353 - val_accuracy: 0.9906
# Epoch 30/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.0349 - val_accuracy: 0.9921
# Epoch 31/100
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0348 - val_accuracy: 0.9903
# Epoch 32/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.0300 - val_accuracy: 0.9918
# Epoch 33/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 34/100
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0318 - val_accuracy: 0.9911
# Epoch 35/100
# 54/54 [==============================] - 3s 61ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0369 - val_accuracy: 0.9912
# Epoch 36/100
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0314 - val_accuracy: 0.9917
# Epoch 37/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0329 - val_accuracy: 0.9929
# Epoch 38/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0359 - val_accuracy: 0.9920
# Epoch 39/100
# 54/54 [==============================] - 4s 72ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0316 - val_accuracy: 0.9933
# Epoch 40/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0316 - val_accuracy: 0.9912
# Epoch 41/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0346 - val_accuracy: 0.9915
# Epoch 42/100
# 54/54 [==============================] - 4s 72ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0364 - val_accuracy: 0.9914
# Epoch 43/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0358 - val_accuracy: 0.9923
# Epoch 44/100
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.0319 - val_accuracy: 0.9917
# Epoch 45/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0338 - val_accuracy: 0.9926
# Epoch 46/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0320 - val_accuracy: 0.9926
# Epoch 47/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.0344 - val_accuracy: 0.9933
# Epoch 48/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0304 - val_accuracy: 0.9915
# Epoch 49/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0315 - val_accuracy: 0.9930
# Epoch 50/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0441 - val_accuracy: 0.9909
# Epoch 51/100
# 54/54 [==============================] - 4s 72ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0360 - val_accuracy: 0.9929
# Epoch 52/100
# 54/54 [==============================] - 4s 71ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0385 - val_accuracy: 0.9915
# Epoch 53/100
# 54/54 [==============================] - 4s 71ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0421 - val_accuracy: 0.9903
# Epoch 54/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0419 - val_accuracy: 0.9905
# Epoch 55/100
# 54/54 [==============================] - 4s 74ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0430 - val_accuracy: 0.9905
# Epoch 56/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0383 - val_accuracy: 0.9923
# Epoch 57/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0388 - val_accuracy: 0.9920
# Epoch 58/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.0426 - val_accuracy: 0.9921
# Epoch 59/100
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0352 - val_accuracy: 0.9918
# Epoch 60/100
# 54/54 [==============================] - 4s 71ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0493 - val_accuracy: 0.9903
# Epoch 61/100
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0437 - val_accuracy: 0.9906
# Epoch 62/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.0343 - val_accuracy: 0.9926
# Epoch 63/100
# 54/54 [==============================] - 3s 61ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.0376 - val_accuracy: 0.9927
# Epoch 64/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0369 - val_accuracy: 0.9911
# Epoch 65/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0343 - val_accuracy: 0.9926
# Epoch 66/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0297 - val_accuracy: 0.9921
# Epoch 67/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0365 - val_accuracy: 0.9917
# Epoch 68/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0319 - val_accuracy: 0.9924
# Epoch 69/100
# 54/54 [==============================] - 3s 57ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.0378 - val_accuracy: 0.9917
# Epoch 70/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0329 - val_accuracy: 0.9921
# Epoch 71/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0366 - val_accuracy: 0.9912
# Epoch 72/100
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0371 - val_accuracy: 0.9917
# Epoch 73/100
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0325 - val_accuracy: 0.9933
# Epoch 74/100
# 54/54 [==============================] - 3s 58ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0291 - val_accuracy: 0.9936
# Epoch 75/100
# 54/54 [==============================] - 3s 60ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0288 - val_accuracy: 0.9938
# Epoch 76/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0373 - val_accuracy: 0.9918
# Epoch 77/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0345 - val_accuracy: 0.9921
# Epoch 78/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0377 - val_accuracy: 0.9926
# Epoch 79/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0336 - val_accuracy: 0.9938
# Epoch 80/100
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.0338 - val_accuracy: 0.9926
# Epoch 81/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0360 - val_accuracy: 0.9930
# Epoch 82/100
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0378 - val_accuracy: 0.9920
# Epoch 83/100
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0360 - val_accuracy: 0.9927
# Epoch 84/100
# 54/54 [==============================] - 3s 60ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0441 - val_accuracy: 0.9924
# Epoch 85/100
# 54/54 [==============================] - 3s 60ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0348 - val_accuracy: 0.9923
# Epoch 86/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0392 - val_accuracy: 0.9917
# Epoch 87/100
# 54/54 [==============================] - 5s 99ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0390 - val_accuracy: 0.9918
# Epoch 88/100
# 54/54 [==============================] - 3s 56ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0369 - val_accuracy: 0.9918
# Epoch 89/100
# 54/54 [==============================] - 3s 58ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0353 - val_accuracy: 0.9933
# Epoch 90/100
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0322 - val_accuracy: 0.9936
# Epoch 91/100
# 54/54 [==============================] - 5s 96ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.0352 - val_accuracy: 0.9930
# Epoch 92/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0371 - val_accuracy: 0.9921
# Epoch 93/100
# 54/54 [==============================] - 5s 97ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0373 - val_accuracy: 0.9923
# Epoch 94/100
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0348 - val_accuracy: 0.9936
# Epoch 95/100
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0317 - val_accuracy: 0.9935
# Epoch 96/100
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0376 - val_accuracy: 0.9921
# Epoch 97/100
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0386 - val_accuracy: 0.9921
# Epoch 98/100
# 54/54 [==============================] - 5s 95ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0361 - val_accuracy: 0.9930
# Epoch 99/100
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0371 - val_accuracy: 0.9929
# Epoch 100/100
# 54/54 [==============================] - 4s 70ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0426 - val_accuracy: 0.9920
# 1051/1051 [==============================] - 27s 26ms/step - loss: 0.0072 - accuracy: 0.9985
# Train loss: 0.007153411395847797, Train accuracy: 0.9985126256942749
# 263/263 [==============================] - 6s 22ms/step - loss: 0.0351 - accuracy: 0.9921
# Test loss: 0.03509070351719856, Test accuracy: 0.9921466112136841

# %%
# %%time
evaluate_model(history,X_tst_tf,y_tst_oh,qmodel)
y_pred=qmodel.predict(X_tst_tf)
# Out:
# Accuracy: 99.21%
# <tensorflow.python.keras.callbacks.History object at 0x000001D9EEE9B820>
# Wall time: 20.8 s

# %%
with tf.device('/cpu:0'):
    start = time.time()
    qmodel.predict(X_tst_tf)
    end = time.time()

inference_time =  (end-start)/X_tst_tf.shape[0]
throughput = X_tst_tf.shape[0]/(end-start)

print("Inference on CPU is :", inference_time)
print("Throughput on CPU is :", throughput, "sequence per second")
# Out:
# Inference on CPU is : 0.00043083987651354694
# Throughput on CPU is : 2321.047921776008 sequence per second

# %%
with tf.device('/gpu:0'):
    start = time.time()
    qmodel.predict(X_tst_tf)
    end = time.time()

inference_time =  (end-start)/X_tst_tf.shape[0]
throughput = X_tst_tf.shape[0]/(end-start)

print("Inference on GPU is :", inference_time)
print("Throughput on GPU is :", throughput, "sequence per second")
# Out:
# Inference on GPU is : 0.0005954493232592692
# Throughput on GPU is : 1679.404041516699 sequence per second

# %%
qmodel.summary()

print_qstats(qmodel)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 319, 1)]          0
# _________________________________________________________________
# Qconv1d_1 (QConv1D)          (None, 319, 16)           144
# _________________________________________________________________
# q_activation_3 (QActivation) (None, 319, 16)           0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 80, 16)            0
# _________________________________________________________________
# Qconv1d_2 (QConv1D)          (None, 80, 16)            2064
# _________________________________________________________________
# q_activation_4 (QActivation) (None, 80, 16)            0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 20, 16)            0
# _________________________________________________________________
# Qconv1d_3 (QConv1D)          (None, 20, 16)            2064
# _________________________________________________________________
# q_activation_5 (QActivation) (None, 20, 16)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 320)               0
# _________________________________________________________________
# OuputLayer (QDense)          (None, 6)                 1926
# _________________________________________________________________
# activation_1 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 6,198
# Trainable params: 6,198
# Non-trainable params: 0
# _________________________________________________________________
#
# Number of operations in model:
#     OuputLayer                    : 1920  (smult_8_8)
#     Qconv1d_1                     : 40832 (smult_8_8)
#     Qconv1d_2                     : 163840 (smult_8_8)
#     Qconv1d_3                     : 40960 (smult_8_8)
#
# Number of operation types in model:
#     smult_8_8                     : 247552
#
# Weight profiling:
#     OuputLayer_weights             : 1920  (8-bit unit)
#     OuputLayer_bias                : 6     (8-bit unit)
#     Qconv1d_1_weights              : 128   (8-bit unit)
#     Qconv1d_1_bias                 : 16    (8-bit unit)
#     Qconv1d_2_weights              : 2048  (8-bit unit)
#     Qconv1d_2_bias                 : 16    (8-bit unit)
#     Qconv1d_3_weights              : 2048  (8-bit unit)
#     Qconv1d_3_bias                 : 16    (8-bit unit)
#
# Weight sparsity:
# ... quantizing model
#     Qconv1d_1                      : 0.0069
#     Qconv1d_2                      : 0.0107
#     Qconv1d_3                      : 0.0078
#     OuputLayer                     : 0.0036
#     ----------------------------------------
#     Total Sparsity                 : 0.0074

# %% [markdown]
# # Commented Code
# from qkeras.utils import *
# model_save_quantized_weights(qmodel, 'qmodel.h5')
# #load_qmodel('qmodel.h5', custom_objects=None, compile=True)

# %%
from qkeras.utils import *

print_model_sparsity(qmodel)
# Out:
# Model Sparsity Summary (model_2)
# --
# Qconv1d_1: (Qconv1d_1/kernel:0, 0.0078125)
# Qconv1d_2: (Qconv1d_2/kernel:0, 0.0107421875)
# Qconv1d_3: (Qconv1d_3/kernel:0, 0.0078125)
# OuputLayer: (OuputLayer/kernel:0, 0.003645833333333348)

# %%
quantized_model_debug(qmodel, X_tst_tf, plot=True)
# Out:
# input                          -11.5861  14.6682
# Qconv1d_1                      -18.5085  20.0546
#  ( -0.9922   0.9922) ( -0.9688  -0.0234) a(  0.500000   1.000000)
# q_activation_3                   0.0000   0.9961
# Qconv1d_2                      -22.3172  11.7814
#  ( -0.9922   0.9922) ( -0.9453   0.3672) a(  0.250000   1.000000)
# q_activation_4                   0.0000   0.9961
# Qconv1d_3                      -14.2619   9.9350
#  ( -0.9922   0.9922) ( -0.8438   0.3281) a(  1.000000   1.000000)
# q_activation_5                   0.0000   0.9961
# OuputLayer                     -39.9914  21.0873
#  ( -0.9922   0.9922) ( -0.4062   0.5469) a(  1.000000   1.000000)

# %%
extract_model_operations(qmodel)
# Out:
# {'Qconv1d_1': {'type': ('mult', (0, 0), (8, 8), (1, 0)),
#   'number_of_operations': 40832,
#   'number_of_weights': 128,
#   'number_of_bias': 16,
#   'type_of_weights': (0, 8, 1),
#   'type_of_bias': (0, 8, 1)},
#  'Qconv1d_2': {'type': ('mult', (0, 0), (8, 8), (1, 0)),
#   'number_of_operations': 163840,
#   'number_of_weights': 2048,
#   'number_of_bias': 16,
#   'type_of_weights': (0, 8, 1),
#   'type_of_bias': (0, 8, 1)},
#  'Qconv1d_3': {'type': ('mult', (0, 0), (8, 8), (1, 0)),
#   'number_of_operations': 40960,
#   'number_of_weights': 2048,
#   'number_of_bias': 16,
#   'type_of_weights': (0, 8, 1),
#   'type_of_bias': (0, 8, 1)},
#  'OuputLayer': {'type': ('mult', (0, 0), (8, 8), (1, 0)),
#   'number_of_operations': 1920,
#   'number_of_weights': 1920,
#   'number_of_bias': 6,
#   'type_of_weights': (0, 8, 1),
#   'type_of_bias': (0, 8, 1)}}

# %%
_, keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(qmodel, keras_file, include_optimizer=False)
print('Saved baseline model to:', keras_file)
# Out:
# Saved baseline model to: C:\Users\mmorsy\AppData\Local\Temp\tmpswrocerq.h5

# %% [markdown]
# ## Prune QKeras Quantized Model

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_callbacks
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_schedule

# %%
import tensorflow_model_optimization as tfmot

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

num_examples = X_trn_tf.shape[0] * (1 - validation_split)
end_step = np.ceil(num_examples / batch_size).astype(np.int32) * epochs

# Define model for pruning.
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.90,
                                                               begin_step=0,
                                                               end_step=end_step)
}

pqmodel = prune_low_magnitude(qmodel, **pruning_params)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-2,
                                                             decay_steps=1000,decay_rate=0.9)
opt = RMSprop(learning_rate=lr_schedule)
    
pqmodel.compile(loss='categorical_crossentropy', optimizer=opt, 
                  metrics=['accuracy'])
pqmodel.summary()
# Out:
# C:\Users\mmorsy\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\base_layer.py:2281: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 319, 1)]          0
# _________________________________________________________________
# prune_low_magnitude_Qconv1d_ (None, 319, 16)           274
# _________________________________________________________________
# prune_low_magnitude_q_activa (None, 319, 16)           1
# _________________________________________________________________
# prune_low_magnitude_max_pool (None, 80, 16)            1
# _________________________________________________________________
# prune_low_magnitude_Qconv1d_ (None, 80, 16)            4114
# _________________________________________________________________
# prune_low_magnitude_q_activa (None, 80, 16)            1
# _________________________________________________________________
# prune_low_magnitude_max_pool (None, 20, 16)            1
# _________________________________________________________________
# prune_low_magnitude_Qconv1d_ (None, 20, 16)            4114
# _________________________________________________________________
# prune_low_magnitude_q_activa (None, 20, 16)            1
# _________________________________________________________________
# prune_low_magnitude_flatten_ (None, 320)               1
# _________________________________________________________________
# prune_low_magnitude_OuputLay (None, 6)                 3848
# _________________________________________________________________
# prune_low_magnitude_activati (None, 6)                 1
# =================================================================
# Total params: 12,357
# Trainable params: 6,198
# Non-trainable params: 6,159
# _________________________________________________________________

# %%
from tempfile import TemporaryDirectory

with TemporaryDirectory() as temp_dir:

    callbacks = [
      tfmot.sparsity.keras.UpdatePruningStep(),
      tfmot.sparsity.keras.PruningSummaries(log_dir=temp_dir),
      EarlyStopping(monitor='val_loss', patience=50),
      ModelCheckpoint(filepath='./int8_pqmodel.h5', 
      monitor='val_accuracy', save_best_only=True)
    ]

    # fit network
    history=pqmodel.fit(X_trn_tf, y_trn_oh, epochs=epochs,callbacks=callbacks, 
                          batch_size=batch_size, validation_split=validation_split,shuffle=True)

pqmodel.load_weights('int8_pqmodel.h5')

train_score = pqmodel.evaluate(X_trn_tf, y_trn_oh)
print('Train loss: {}, Train accuracy: {}'.format(train_score[0], train_score[1]))
test_score = pqmodel.evaluate(X_tst_tf, y_tst_oh)
print('Test loss: {}, Test accuracy: {}'.format(test_score[0], test_score[1]))
# Out:
# Epoch 1/100
#  6/54 [==>...........................] - ETA: 4:50 - loss: 0.0343 - accuracy: 0.9892WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0511s vs `on_train_batch_end` time: 4.9973s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0511s vs `on_train_batch_end` time: 4.9973s). Check your callbacks.
# 54/54 [==============================] - 51s 708ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0450 - val_accuracy: 0.9912
# Epoch 2/100
# 54/54 [==============================] - 5s 84ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0660 - val_accuracy: 0.9829
# Epoch 3/100
# 54/54 [==============================] - 5s 83ms/step - loss: 0.0214 - accuracy: 0.9930 - val_loss: 0.0455 - val_accuracy: 0.9894
# Epoch 4/100
# 54/54 [==============================] - 5s 87ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.0493 - val_accuracy: 0.9891
# Epoch 5/100
# 54/54 [==============================] - 5s 86ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0406 - val_accuracy: 0.9906
# Epoch 6/100
# 54/54 [==============================] - 5s 95ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0413 - val_accuracy: 0.9908
# Epoch 7/100
# 54/54 [==============================] - 5s 88ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0411 - val_accuracy: 0.9900
# Epoch 8/100
# 54/54 [==============================] - 5s 89ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0420 - val_accuracy: 0.9903
# Epoch 9/100
# 54/54 [==============================] - 5s 84ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0412 - val_accuracy: 0.9909
# Epoch 10/100
# 54/54 [==============================] - 5s 84ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0380 - val_accuracy: 0.9923 0s - loss: 0.0051 - accuracy: 0.99 - ETA: 0s - loss: 0.0051 - accuracy:
# Epoch 11/100
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0439 - val_accuracy: 0.9905
# Epoch 12/100
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0400 - val_accuracy: 0.9903 loss: 0.0062 - accuracy: 0.99
# Epoch 13/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0503 - val_accuracy: 0.9875
# Epoch 14/100
# 54/54 [==============================] - 7s 123ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0412 - val_accuracy: 0.9909
# Epoch 15/100
# 54/54 [==============================] - 6s 112ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0412 - val_accuracy: 0.9902
# Epoch 16/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0407 - val_accuracy: 0.9906- loss: 0.0079 - accuracy:  - ETA: 0s - loss: 0.0 - ETA: 0s - loss: 0.0075 - accuracy: 0.99
# Epoch 17/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.0395 - val_accuracy: 0.9900
# Epoch 18/100
# 54/54 [==============================] - 7s 136ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.0362 - val_accuracy: 0.9920
# Epoch 19/100
# 54/54 [==============================] - 6s 111ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0453 - val_accuracy: 0.9883
# Epoch 20/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0356 - val_accuracy: 0.9905
# Epoch 21/100
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0377 - val_accuracy: 0.9900
# Epoch 22/100
# 54/54 [==============================] - 5s 90ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.0389 - val_accuracy: 0.9888.
# Epoch 23/100
# 54/54 [==============================] - 5s 91ms/step - loss: 0.0094 - accuracy: 0.9975 - val_loss: 0.0366 - val_accuracy: 0.9909
# Epoch 24/100
# 54/54 [==============================] - 5s 100ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.0359 - val_accuracy: 0.9905
# Epoch 25/100
# 54/54 [==============================] - 10s 185ms/step - loss: 0.0285 - accuracy: 0.9903 - val_loss: 0.0376 - val_accuracy: 0.9896
# Epoch 26/100
# 54/54 [==============================] - 7s 126ms/step - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.0392 - val_accuracy: 0.9894
# Epoch 27/100
# 54/54 [==============================] - 4s 79ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0370 - val_accuracy: 0.9917: 0.0113 - accuracy: 0. - ETA: 1s -
# Epoch 28/100
# 54/54 [==============================] - 4s 80ms/step - loss: 0.0087 - accuracy: 0.9979 - val_loss: 0.0451 - val_accuracy: 0.9881
# Epoch 29/100
# 54/54 [==============================] - 4s 79ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0409 - val_accuracy: 0.9890
# Epoch 30/100
# 54/54 [==============================] - 4s 79ms/step - loss: 0.0124 - accuracy: 0.9964 - val_loss: 0.0401 - val_accuracy: 0.9893
# Epoch 31/100
# 54/54 [==============================] - 8s 144ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.0384 - val_accuracy: 0.9888
# Epoch 32/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0173 - accuracy: 0.9952 - val_loss: 0.0453 - val_accuracy: 0.9863
# Epoch 33/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0246 - accuracy: 0.9919 - val_loss: 0.0422 - val_accuracy: 0.9881
# Epoch 34/100
# 54/54 [==============================] - 5s 83ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 0.0400 - val_accuracy: 0.9885
# Epoch 35/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.0393 - val_accuracy: 0.9887A: 0s - loss: 0.0147
# Epoch 36/100
# 54/54 [==============================] - 4s 80ms/step - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.0423 - val_accuracy: 0.9869
# Epoch 37/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0384 - val_accuracy: 0.9884
# Epoch 38/100
# 54/54 [==============================] - 6s 120ms/step - loss: 0.0373 - accuracy: 0.9880 - val_loss: 0.0347 - val_accuracy: 0.9905
# Epoch 39/100
# 54/54 [==============================] - 4s 75ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.0572 - val_accuracy: 0.9844ETA: 1s - loss: 0.0156 - accuracy: 0.99 - ETA: 1s - loss: 0.0 - ETA: 0s - loss: 0.0159 - accuracy: 0. - ETA: 0s - loss: 0.016
# Epoch 40/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0335 - accuracy: 0.9892 - val_loss: 0.0414 - val_accuracy: 0.9883ss: 0.0338 - accuracy
# Epoch 41/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.0497 - val_accuracy: 0.9859
# Epoch 42/100
# 54/54 [==============================] - 7s 130ms/step - loss: 0.0245 - accuracy: 0.9938 - val_loss: 0.0384 - val_accuracy: 0.9887
# Epoch 43/100
# 54/54 [==============================] - 5s 83ms/step - loss: 0.0241 - accuracy: 0.9938 - val_loss: 0.0444 - val_accuracy: 0.9872 0s - loss: 0.0241 - accura
# Epoch 44/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0234 - accuracy: 0.9933 - val_loss: 0.0436 - val_accuracy: 0.9865
# Epoch 45/100
# 54/54 [==============================] - 6s 112ms/step - loss: 0.0267 - accuracy: 0.9930 - val_loss: 0.0462 - val_accuracy: 0.9868s: 0.0265 - accu
# Epoch 46/100
# 54/54 [==============================] - 5s 97ms/step - loss: 0.0248 - accuracy: 0.9931 - val_loss: 0.0407 - val_accuracy: 0.9891
# Epoch 47/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0304 - accuracy: 0.9916 - val_loss: 0.0492 - val_accuracy: 0.9863
# Epoch 48/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0330 - accuracy: 0.9902 - val_loss: 0.0456 - val_accuracy: 0.98650.0333
# Epoch 49/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0409 - accuracy: 0.9885 - val_loss: 0.0487 - val_accuracy: 0.986964 - accu - ETA - ETA: 0s - loss: 0.0411
# Epoch 50/100
# 54/54 [==============================] - 7s 132ms/step - loss: 0.0320 - accuracy: 0.9917 - val_loss: 0.0802 - val_accuracy: 0.9798
# Epoch 51/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0571 - accuracy: 0.9844 - val_loss: 0.0572 - val_accuracy: 0.9838
# Epoch 52/100
# 54/54 [==============================] - 4s 75ms/step - loss: 0.0408 - accuracy: 0.9890 - val_loss: 0.0558 - val_accuracy: 0.9850
# Epoch 53/100
# 54/54 [==============================] - 6s 112ms/step - loss: 0.0395 - accuracy: 0.9893 - val_loss: 0.0492 - val_accuracy: 0.9868
# Epoch 54/100
# 54/54 [==============================] - 5s 86ms/step - loss: 0.0389 - accuracy: 0.9900 - val_loss: 0.0571 - val_accuracy: 0.9830 - accuracy: 0.99 -
# Epoch 55/100
# 54/54 [==============================] - 6s 109ms/step - loss: 0.0382 - accuracy: 0.9900 - val_loss: 0.0552 - val_accuracy: 0.9847
# Epoch 56/100
# 54/54 [==============================] - 5s 84ms/step - loss: 0.0413 - accuracy: 0.9900 - val_loss: 0.0642 - val_accuracy: 0.9829
# Epoch 57/100
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0496 - accuracy: 0.9866 - val_loss: 0.0585 - val_accuracy: 0.9833
# Epoch 58/100
# 54/54 [==============================] - 5s 89ms/step - loss: 0.0483 - accuracy: 0.9877 - val_loss: 0.0601 - val_accuracy: 0.9848
# Epoch 59/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0451 - accuracy: 0.9886 - val_loss: 0.0563 - val_accuracy: 0.9847
# Epoch 60/100
# 54/54 [==============================] - 5s 87ms/step - loss: 0.0523 - accuracy: 0.9868 - val_loss: 0.0703 - val_accuracy: 0.9793
# Epoch 61/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0524 - accuracy: 0.9868 - val_loss: 0.0632 - val_accuracy: 0.9827
# Epoch 62/100
# 54/54 [==============================] - 6s 112ms/step - loss: 0.0556 - accuracy: 0.9854 - val_loss: 0.0651 - val_accuracy: 0.9829
# Epoch 63/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0518 - accuracy: 0.9861 - val_loss: 0.1144 - val_accuracy: 0.9667
# Epoch 64/100
# 54/54 [==============================] - 6s 112ms/step - loss: 0.0866 - accuracy: 0.9759 - val_loss: 0.0688 - val_accuracy: 0.9822
# Epoch 65/100
# 54/54 [==============================] - 5s 85ms/step - loss: 0.0578 - accuracy: 0.9856 - val_loss: 0.0682 - val_accuracy: 0.9822
# Epoch 66/100
# 54/54 [==============================] - 6s 110ms/step - loss: 0.0603 - accuracy: 0.9850 - val_loss: 0.0708 - val_accuracy: 0.9807
# Epoch 67/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0577 - accuracy: 0.9864 - val_loss: 0.0649 - val_accuracy: 0.9838
# Epoch 68/100
# 54/54 [==============================] - 4s 75ms/step - loss: 0.0551 - accuracy: 0.9871 - val_loss: 0.0635 - val_accuracy: 0.98290.0547 - ac - - ETA: 0s - loss: 0.0549 - accu - ETA: 0s - loss: 0.0550 - accuracy:
# Epoch 69/100
# 54/54 [==============================] - 7s 125ms/step - loss: 0.0537 - accuracy: 0.9871 - val_loss: 0.0704 - val_accuracy: 0.9825
# Epoch 70/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0606 - accuracy: 0.9844 - val_loss: 0.0657 - val_accuracy: 0.9835A: 1s - loss: 0.0624 - accuracy - E
# Epoch 71/100
# 54/54 [==============================] - 4s 78ms/step - loss: 0.0566 - accuracy: 0.9854 - val_loss: 0.0745 - val_accuracy: 0.9807s - loss: 0.0545 -  - ETA: 1s - loss: 0 - ETA: 0s - loss: 0.0562 - ac
# Epoch 72/100
# 54/54 [==============================] - 6s 110ms/step - loss: 0.0617 - accuracy: 0.9834 - val_loss: 0.0655 - val_accuracy: 0.9845
# Epoch 73/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0602 - accuracy: 0.9845 - val_loss: 0.0684 - val_accuracy: 0.9839 0s - loss: 0.0603 -
# Epoch 74/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0592 - accuracy: 0.9859 - val_loss: 0.0669 - val_accuracy: 0.9854acy - ETA: 0s - los
# Epoch 75/100
# 54/54 [==============================] - 6s 117ms/step - loss: 0.0577 - accuracy: 0.9851 - val_loss: 0.0677 - val_accuracy: 0.9833 0.0576 - accu
# Epoch 76/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0608 - accuracy: 0.9849 - val_loss: 0.0668 - val_accuracy: 0.98428
# Epoch 77/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0615 - accuracy: 0.9856 - val_loss: 0.0694 - val_accuracy: 0.9845- ETA: 1s - loss: 0.0 - ETA
# Epoch 78/100
# 54/54 [==============================] - 7s 128ms/step - loss: 0.0595 - accuracy: 0.9854 - val_loss: 0.0807 - val_accuracy: 0.9807
# Epoch 79/100
# 54/54 [==============================] - 5s 84ms/step - loss: 0.0679 - accuracy: 0.9825 - val_loss: 0.0739 - val_accuracy: 0.9817
# Epoch 80/100
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0610 - accuracy: 0.9843 - val_loss: 0.0728 - val_accuracy: 0.9819
# Epoch 81/100
# 54/54 [==============================] - 5s 88ms/step - loss: 0.0646 - accuracy: 0.9843 - val_loss: 0.0730 - val_accuracy: 0.9816
# Epoch 82/100
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0661 - accuracy: 0.9848 - val_loss: 0.0759 - val_accuracy: 0.9801
# Epoch 83/100
# 54/54 [==============================] - 5s 85ms/step - loss: 0.0683 - accuracy: 0.9834 - val_loss: 0.0766 - val_accuracy: 0.9801
# Epoch 84/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0658 - accuracy: 0.9843 - val_loss: 0.0776 - val_accuracy: 0.9802
# Epoch 85/100
# 54/54 [==============================] - 7s 138ms/step - loss: 0.0645 - accuracy: 0.9850 - val_loss: 0.0746 - val_accuracy: 0.9807
# Epoch 86/100
# 54/54 [==============================] - 4s 76ms/step - loss: 0.0673 - accuracy: 0.9835 - val_loss: 0.0760 - val_accuracy: 0.9808
# Epoch 87/100
# 54/54 [==============================] - 4s 79ms/step - loss: 0.0646 - accuracy: 0.9846 - val_loss: 0.0741 - val_accuracy: 0.9825-
# Epoch 88/100
# 54/54 [==============================] - 4s 77ms/step - loss: 0.0627 - accuracy: 0.9852 - val_loss: 0.0755 - val_accuracy: 0.9814- loss: 0.0618 - accu - ETA: 1s - loss: 0.0618 - accuracy: 0.98 - ETA: 1s - loss: 0.0618  - ETA: 0s - loss:
# 1051/1051 [==============================] - 21s 20ms/step - loss: 0.0118 - accuracy: 0.9974
# Train loss: 0.011815215460956097, Train accuracy: 0.9973822236061096
# 263/263 [==============================] - 5s 18ms/step - loss: 0.0398 - accuracy: 0.9898
# Test loss: 0.03983043506741524, Test accuracy: 0.9897667765617371

# %%
_, pq_model_accuracy = pqmodel.evaluate(X_tst_tf, y_tst_oh, verbose=0)
print('Pruned test accuracy:', pq_model_accuracy)
# Out:
# Pruned test accuracy: 0.9897667765617371

# %%
# %%time
evaluate_model(history,X_tst_tf,y_tst_oh,pqmodel)
y_pred=pqmodel.predict(X_tst_tf)
# Out:
# Accuracy: 98.98%
# <tensorflow.python.keras.callbacks.History object at 0x000001D888F55460>
# Wall time: 15 s

# %%
with tf.device('/cpu:0'):
    start = time.time()
    pqmodel.predict(X_tst_tf)
    end = time.time()

inference_time =  (end-start)/X_tst_tf.shape[0]
throughput = X_tst_tf.shape[0]/(end-start)

print("Inference on CPU is :", inference_time)
print("Throughput on CPU is :", throughput, "sequence per second")
# Out:
# Inference on CPU is : 0.0006529440600664374
# Throughput on CPU is : 1531.524767831182 sequence per second

# %%
with tf.device('/gpu:0'):
    start = time.time()
    pqmodel.predict(X_tst_tf)
    end = time.time()

inference_time =  (end-start)/X_tst_tf.shape[0]
throughput = X_tst_tf.shape[0]/(end-start)

print("Inference on GPU is :", inference_time)
print("Throughput on GPU is :", throughput, "sequence per second")
# Out:
# Inference on GPU is : 0.0004752644580185612
# Throughput on GPU is : 2104.091697008291 sequence per second

# %%
pq_model = tfmot.sparsity.keras.strip_pruning(pqmodel)

_, pq_keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(pq_model, pq_keras_file, include_optimizer=False)
print('Saved pruned Keras model to:', pq_keras_file)
# Out:
# Saved pruned Keras model to: C:\Users\mmorsy\AppData\Local\Temp\tmpbfd0r1ea.h5

# %% [markdown]
# ## Convert Pruned Quantized Model to tflite

# %%
## Convert pruned model to tflite without optimizations
converter = tf.lite.TFLiteConverter.from_keras_model(pq_model)
pq_tflite_model = converter.convert()

_, pq_tflite_file = tempfile.mkstemp('.tflite')

with open(pq_tflite_file, 'wb') as f:
  f.write(pq_tflite_model)

print('Saved pruned TFLite model to:', pq_tflite_file)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmp8x2ujg0l\assets
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmp8x2ujg0l\assets
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# to_proto not supported in EAGER mode.
# Saved pruned TFLite model to: C:\Users\mmorsy\AppData\Local\Temp\tmp4egiylj9.tflite

# %%
def get_gzipped_model_size(file):
  # Returns size of gzipped model, in bytes.
  import os
  import zipfile

  _, zipped_file = tempfile.mkstemp('.zip')
  with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(file)

  return os.path.getsize(zipped_file)

# %%
print("Size of gzipped baseline Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned Keras model: %.2f bytes" % (get_gzipped_model_size(pq_keras_file)))
print("Size of gzipped pruned TFlite model: %.2f bytes" % (get_gzipped_model_size(pq_tflite_file)))
# Out:
# Size of gzipped baseline Keras model: 13089.00 bytes
# Size of gzipped pruned Keras model: 14784.00 bytes
# Size of gzipped pruned TFlite model: 9889.00 bytes

# %%
## Convert pruned model to tflite without optimizations

converter = tf.lite.TFLiteConverter.from_keras_model(pq_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
pq_tflite_model = converter.convert()

_, pq_tflite_file = tempfile.mkstemp('.tflite')

f=open(pq_tflite_file, 'wb') 
f.write(pq_tflite_model)
f.close()

print('Saved quantized and pruned TFLite model to:', quantized_and_pruned_tflite_file)

print("Size of gzipped baseline Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pq_tflite_file)))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmpn34wrjrk\assets
# INFO:tensorflow:Assets written to: C:\Users\mmorsy\AppData\Local\Temp\tmpn34wrjrk\assets
# Saved quantized and pruned TFLite model to: C:\Users\mmorsy\AppData\Local\Temp\tmpvs1xl0gj.tflite
# Size of gzipped baseline Keras model: 13089.00 bytes
# Size of gzipped pruned and quantized TFlite model: 8315.00 bytes

# %%
import numpy as np

def evaluate_model(interpreter):
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  # Run predictions on ever y image in the "test" dataset.
  prediction_results = []
  for i, test_example in enumerate(X_tst_tf):
    if i % 1000 == 0:
      print('Evaluated on {n} results so far.'.format(n=i))
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_example = np.expand_dims(test_example, axis=0).astype(np.float32)
    interpreter.set_tensor(input_index, test_example)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the digit with highest
    # probability.
    output = interpreter.tensor(output_index)
    digit = np.argmax(output()[0])
    prediction_results.append(digit)

  print('\n')
  # Compare prediction results with ground truth labels to calculate accuracy.
  prediction_digits = np.array(prediction_results)
  accuracy = (prediction_results == y_tst).mean()
  return accuracy

# %%
interpreter = tf.lite.Interpreter(model_content=pq_tflite_model)
interpreter.allocate_tensors()

test_accuracy = evaluate_model(interpreter)

print('Pruned and quantized TFLite test_accuracy:', test_accuracy)
print('Pruned TF test accuracy:', pq_model_accuracy)
# Out:
# Evaluated on 0 results so far.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
# Evaluated on 3000 results so far.
# Evaluated on 4000 results so far.
# Evaluated on 5000 results so far.
# Evaluated on 6000 results so far.
# Evaluated on 7000 results so far.
# Evaluated on 8000 results so far.
#
#
# Pruned and quantized TFLite test_accuracy: 0.9897667777248929
# Pruned TF test accuracy: 0.9897667765617371

# %%
def get_flops(model):
    session = tf.compat.v1.Session()
    graph = tf.compat.v1.get_default_graph()   

    with graph.as_default():
        with session.as_default():
            model = tf.keras.models.load_model(model)

            run_meta = tf.compat.v1.RunMetadata()
            opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        
            # We use the Keras session graph in the call to the profiler.
            flops = tf.compat.v1.profiler.profile(graph=graph,
                                                  run_meta=run_meta, cmd='op', options=opts)
        
            return flops.total_float_ops

get_flops('base_model.h5')
# Out:
# 32784
